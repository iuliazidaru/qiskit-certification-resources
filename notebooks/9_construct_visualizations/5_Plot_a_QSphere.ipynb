# %% [markdown]
# What is the qsphere? 1 Minute Qiskit https://www.youtube.com/watch?v=4SoK2h4a7us
#
# https://quantum-computing.ibm.com/composer/docs/iqx/visualizations#download-visualizations

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import DensityMatrix
from qiskit.visualization import plot_state_qsphere

# %% [markdown]
# # Bell state 00

# %%
bell_00 = QuantumCircuit(2)
bell_00.h(0)
bell_00.cx(0, 1)
print(bell_00)

state = DensityMatrix.from_instruction(bell_00)
plot_state_qsphere(state)

# Bell state 10
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# /Users/iuliazidaru/opt/anaconda3/envs/qiskit-certification-resources/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:705: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   xs, ys, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
bell_10 = QuantumCircuit(2)
bell_10.h(0)
bell_10.x(1)
bell_10.cx(0, 1)
print(bell_10)

state = DensityMatrix.from_instruction(bell_10)
plot_state_qsphere(state)
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      ├───┤┌─┴─┐
# q_1: ┤ X ├┤ X ├
#      └───┘└───┘
# /Users/iuliazidaru/opt/anaconda3/envs/qiskit-certification-resources/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:705: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   xs, ys, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# # Bell state 01

# %%
bell_01 = QuantumCircuit(2)
bell_01.x(0)
bell_01.h(0)
bell_01.cx(0, 1)
print(bell_01)

state = DensityMatrix.from_instruction(bell_01)
plot_state_qsphere(state)
# Out:
#      ┌───┐┌───┐
# q_0: ┤ X ├┤ H ├──■──
#      └───┘└───┘┌─┴─┐
# q_1: ──────────┤ X ├
#                └───┘
# /Users/iuliazidaru/opt/anaconda3/envs/qiskit-certification-resources/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:705: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   xs, ys, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# # Bell state 11

# %%
bell_11 = QuantumCircuit(2)
bell_11.x(0)
bell_11.h(0)
bell_11.x(1)
bell_11.cx(0, 1)
print(bell_11)

state = DensityMatrix.from_instruction(bell_11)
plot_state_qsphere(state)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3aa70a337345> in <module>
# ----> 1 bell_11 = QuantumCircuit(2)
#       2 bell_11.x(0)
#       3 bell_11.h(0)
#       4 bell_11.x(1)
#       5 bell_11.cx(0, 1)
#
# NameError: name 'QuantumCircuit' is not defined

# %%
circ_6 = QuantumCircuit(6)
circ_6.h(range(0,6))
state = DensityMatrix.from_instruction(circ_6)
plot_state_qsphere(state)
# Out:
# /Users/iuliazidaru/opt/anaconda3/envs/qiskit-certification-resources/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:705: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   xs, ys, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
circ_4 = QuantumCircuit(4)
circ_4.h(range(0,4))
state = DensityMatrix.from_instruction(circ_4)
plot_state_qsphere(state)
# Out:
# /Users/iuliazidaru/opt/anaconda3/envs/qiskit-certification-resources/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:705: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   xs, ys, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
circ_2 = QuantumCircuit(2)
circ_2.h(range(0,2))
state = DensityMatrix.from_instruction(circ_2)
plot_state_qsphere(state)
# Out:
# /Users/iuliazidaru/opt/anaconda3/envs/qiskit-certification-resources/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:705: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   xs, ys, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
